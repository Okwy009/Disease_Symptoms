# %%
# Loading Libraries 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Loading Cleaned Dataset
df_cleaned = pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\Data_Analyst\Disease_Symptoms_Patients\datasets\Cleaned_Disease_Symptoms_Patients.csv')
df_cleaned
# Out:
#          Disease  Fever  Cough  Fatigue  Difficulty Breathing  Age  Gender  \
# 0      Influenza      1      0        1                     1   19  Female
# 1    Common Cold      0      1        1                     0   25  Female
# 2         Eczema      0      1        1                     0   25  Female
# 3         Asthma      1      1        0                     1   25    Male
# 4         Asthma      1      1        0                     1   25    Male
# ..           ...    ...    ...      ...                   ...  ...     ...
# 344       Stroke      1      0        1                     0   80  Female
# 345       Stroke      1      0        1                     0   85    Male
# 346       Stroke      1      0        1                     0   85    Male
# 347       Stroke      1      0        1                     0   90  Female
# 348       Stroke      1      0        1                     0   90  Female
#
#      Blood Pressure  Cholesterol Level Outcome Variable    Age Group
# ...

# %%
df_cleaned.describe()
# Out:
#             Fever       Cough    Fatigue  Difficulty Breathing         Age  \
# count  349.000000  349.000000  349.00000            349.000000  349.000000
# mean     0.501433    0.478510    0.69341              0.252149   46.323782
# std      0.500716    0.500255    0.46174              0.434870   13.085090
# min      0.000000    0.000000    0.00000              0.000000   19.000000
# 25%      0.000000    0.000000    0.00000              0.000000   35.000000
# 50%      1.000000    0.000000    1.00000              0.000000   45.000000
# 75%      1.000000    1.000000    1.00000              1.000000   55.000000
# max      1.000000    1.000000    1.00000              1.000000   90.000000
#
#        Blood Pressure  Cholesterol Level
# count      349.000000         349.000000
# mean         1.426934           1.378223
# std          0.590604           0.656695
# min          0.000000           0.000000
# 25%          1.000000           1.000000
# 50%          1.000000           1.000000
# ...

# %% [markdown]
# - Age distribution across symptoms

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_cleaned['Age'], bins=30, kde=True)
plt.title('Age Distribution')
plt.grid('True')
plt.show()

# %% [markdown]
# - Correlation Analysis

# %%
# Select only numeric columns
numeric_df = df_cleaned.select_dtypes(include=['number'])

# Calculate the correlation matrix for numeric columns
plt.figure(figsize=(12, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Health Symptoms and Indicators')

plt.show()

# %%
# Pie chart for gender distribution of Fever symptom (example)
gender_distribution = df_cleaned.groupby('Fever')['Gender'].value_counts().unstack().fillna(0)
gender_distribution = gender_distribution.loc[1]  # Focus on Fever occurrence (1 for Yes)

# Pie chart visualization
plt.figure(figsize=(6,6))
gender_distribution.plot.pie(autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff'])
plt.title('Gender Distribution of Fever')
plt.ylabel('')
plt.show()
